# %% [markdown]
# <a href="https://colab.research.google.com/github/Senamile1/Senamile1/blob/main/Bash%7Cpython%7Cgit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Question 1.1:

# %%
! wget https://storage.googleapis.com/bdt-beam/users_v.csv
# Out:
# --2022-08-10 17:28:29--  https://storage.googleapis.com/bdt-beam/users_v.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.2.128, 2607:f8b0:4023:c0d::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.2.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 143675 (140K) [text/csv]
# Saving to: ‘users_v.csv.1’
#
# users_v.csv.1       100%[===================>] 140.31K  --.-KB/s    in 0.001s
#
# 2022-08-10 17:28:29 (110 MB/s) - ‘users_v.csv.1’ saved [143675/143675]

# %% [markdown]
# Question 1.2:

# %%
! cat users_v.csv | head -10
# Out:
# user_id,name,gender,age,address,date_joined
# 1,Anthony Wolf,male,73,New Rachelburgh-VA-49583,2019/03/13
# 2,James Armstrong,male,56,North Jillianfort-UT-86454,2020/11/06
# 3,Cody Shaw,male,75,North Anne-SC-53799,2004/05/29
# 4,Sierra Hamilton,female,76,New Angelafurt-ME-46190,2005/08/26
# 5,Chase Davis,male,31,South Bethmouth-WI-18562,2018/04/30
# 6,Sierra Andrews,female,21,Ryanville-MI-69690,2007/05/25
# 7,Ann Stone,female,41,Smithmouth-SD-17340,2005/01/05
# 8,Karen Santos,female,34,Mariaville-AK-29888,2003/12/12
# 9,Ronald Meyer,male,41,North Cherylhaven-NJ-04197,2015/11/14

# %% [markdown]
# Question 1.3

# %%
! cat users_v.csv | wc -l
# Out:
# 2358

# %% [markdown]
# Question 1.4

# %%
# !shuf -n 1000 users_v.csv > users_sample.csv
! cat users_sample.csv | wc -l
# Out:
# 1000

# %% [markdown]
# Question 1.5.1

# %%
! sort -n users_sample.csv
# Out:
# user_id,name,gender,age,address,date_joined
# 3,Cody Shaw,male,75,North Anne-SC-53799,2004/05/29
# 7,Ann Stone,female,41,Smithmouth-SD-17340,2005/01/05
# 12,Anna Glenn,female,73,Lake Pamela-NY-61706,2013/09/27
# 13,Kenneth Martinez,male,21,West Kimberly-AZ-87210,2002/03/13
# 15,Timothy Jones,male,68,Wilsonport-MT-95064,2015/11/13
# 18,Steven Myers,male,72,North Christinaside-ME-79432,2008/08/09
# 19,Justin Beasley,male,50,Whiteport-GA-29233,2000/08/09
# 23,Stephanie Williamson,female,22,Brittanyton-DC-24346,2003/03/09
# 25,Mrs. Michele Fuller,female,29,Taylorhaven-CT-97167,2010/11/14
# 27,Kenneth Montgomery,male,55,South Christinemouth-SC-54543,2000/06/20
# 29,Joseph Nelson,male,24,Phamside-OR-38312,2004/07/30
# 33,Andrew Watkins,male,45,Terrellchester-NM-38781,2007/10/10
# 36,Brandon White,male,42,Jennifershire-CA-09827,2004/06/21
# 39,Kevin Rose,male,30,East Josephport-DE-13217,2007/06/07
# 42,Alexandria Taylor,female,48,Brewerhaven-MT-66936,2014/11/15
# ...

# %% [markdown]
# Question 1.5.2

# %%
# !sort -k1 -n users_sample.csv> users_sample.csv

# %% [markdown]
# Question 1.5.3

# %%
! cat users_sample.csv | tail -10
# Out:
# 1137,Theresa Brown,female,45,West Kimberly-CT-26809,2010/11/29
# 1937,Joseph Taylor,male,33,Chambersland-MO-45625,2009/01/20
# 2037,Brandon Edwards,male,18,Bradleyview-IN-89331,2013/08/08
# 1330,Karen Chung,female,24,South Tammyborough-KY-30823,2012/10/29
# 1007,Eric Jackson,male,49,New Elizabeth-OK-81325,2016/02/22
# 1167,Heidi Doyle,female,38,Smithburgh-ID-40975,2020/02/26
# 1829,Phillip Freeman,male,60,Lake Jessica-MN-87745,2004/01/06
# 731,Briana Riley,female,73,New Ethanmouth-TX-03903,2006/04/08
# 1287,Michelle Reyes,female,48,Lake Jerrybury-ND-84051,2014/06/30
# 1396,Lori Donaldson,female,30,Andrewside-VA-45614,2014/08/13

# %% [markdown]
# Question 2.1

# %%
import pandas as pd

# %%
df = pd.read_csv("users_v.csv")
print(df)
# Out:
#       user_id                 name  gender  age                     address  \
# 0           1         Anthony Wolf    male   73    New Rachelburgh-VA-49583
# 1           2      James Armstrong    male   56  North Jillianfort-UT-86454
# 2           3            Cody Shaw    male   75         North Anne-SC-53799
# 3           4      Sierra Hamilton  female   76     New Angelafurt-ME-46190
# 4           5          Chase Davis    male   31    South Bethmouth-WI-18562
# ...       ...                  ...     ...  ...                         ...
# 2352     2353      Brittney Graham  female   40          Brownland-CO-71229
# 2353     2354      Allison Schmidt  female   43         Port Logan-MD-38588
# 2354     2355  Christopher Johnson    male   68    North Justinton-VA-32798
# 2355     2356           Mark Brown    male   67     New Kayleefurt-MA-82581
# 2356     2357      Steven Robinson    male   45          Mistytown-HI-31737
#
#      date_joined
# 0     2019/03/13
# 1     2020/11/06
# ...

# %% [markdown]
# Question 2.2

# %%
df.head(10)
# Out:
#    user_id             name  gender  age                     address  \
# 0        1     Anthony Wolf    male   73    New Rachelburgh-VA-49583
# 1        2  James Armstrong    male   56  North Jillianfort-UT-86454
# 2        3        Cody Shaw    male   75         North Anne-SC-53799
# 3        4  Sierra Hamilton  female   76     New Angelafurt-ME-46190
# 4        5      Chase Davis    male   31    South Bethmouth-WI-18562
# 5        6   Sierra Andrews  female   21          Ryanville-MI-69690
# 6        7        Ann Stone  female   41         Smithmouth-SD-17340
# 7        8     Karen Santos  female   34         Mariaville-AK-29888
# 8        9     Ronald Meyer    male   41  North Cherylhaven-NJ-04197
# 9       10    Steven Rivera    male   43          Wayneside-VT-29040
#
#   date_joined
# 0  2019/03/13
# 1  2020/11/06
# 2  2004/05/29
# 3  2005/08/26
# 4  2018/04/30
# 5  2007/05/25
# 6  2005/01/05
# 7  2003/12/12
# 8  2015/11/14
# 9  2003/05/15

# %% [markdown]
# Question 2.3

# %%
print(min(df.age), max(df.age))
# Out:
# 18 80

# %% [markdown]
# Question 2.4

# %%
import numpy as np

# %%
df['age'].describe()
# Out:
# count    2357.000000
# mean       49.054731
# std        18.206348
# min        18.000000
# 25%        33.000000
# 50%        49.000000
# 75%        65.000000
# max        80.000000
# Name: age, dtype: float64

# %% [markdown]
# Question 2.5.1

# %%
df.loc[df['name'].str.split().str.len() == 2, 'surname'] = df['name'].str.split().str[-1]

# %% [markdown]
# Question 5.2.2

# %%
df.tail(10)
# Out:
#       user_id                 name  gender  age                    address  \
# 2347     2348     Victoria Edwards  female   68    Lake Jamesberg-NY-88824
# 2348     2349          Chris Ellis    male   46  Port Richardside-NY-77994
# 2349     2350       Kimberly Smith  female   19      East Anthony-GA-00646
# 2350     2351       William Nelson    male   67   Lake Parkerside-MN-06905
# 2351     2352          Nancy Clark  female   80        Jamesshire-AK-88437
# 2352     2353      Brittney Graham  female   40         Brownland-CO-71229
# 2353     2354      Allison Schmidt  female   43        Port Logan-MD-38588
# 2354     2355  Christopher Johnson    male   68   North Justinton-VA-32798
# 2355     2356           Mark Brown    male   67    New Kayleefurt-MA-82581
# 2356     2357      Steven Robinson    male   45         Mistytown-HI-31737
#
#      date_joined
# 2347  2001/09/03
# 2348  2011/03/18
# 2349  2021/06/20
# 2350  2005/12/21
# 2351  2001/12/12
# 2352  2005/07/10
# ...

# %% [markdown]
# Question 2.6.1

# %%
df['date_joined'] = pd.to_datetime(df.date_joined)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-07a208349b03> in <module>()
# ----> 1 df['date_joined'] = pd.to_datetime(df.date_joined)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     881                 result = result.tz_localize(tz)  # type: ignore[call-arg]
#     882     elif isinstance(arg, ABCSeries):
# --> 883         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#     884         if not cache_array.empty:
#     885             result = arg.map(cache_array)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/tools/datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     193         unique_dates = unique(arg)
#     194         if len(unique_dates) < len(arg):
# ...
